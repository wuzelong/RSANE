# %%
! pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Classification

# %%
! python classification.py --data='WebKB' --eta1=1.1 --eta2=3 --gam1=4 --gam2=3 --alpha=0.47 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
# Out:
# ten-fold:
# 0.7816 0.6652
# train radio from 0.1 to 0.9:
# 0.6152 0.4337
# 0.6614 0.4975
# 0.6897 0.5257
# 0.7019 0.5516
# 0.72 0.5765
# 0.7222 0.5993
# 0.7241 0.5984
# 0.7306 0.5962
# 0.7333 0.5471

# %%
! python classification.py --data='Cora' --eta1=0.039 --eta2=0.049 --gam1=6 --gam2=2 --alpha=0.4 --mu=0.5 --ksi=0.91 --adj_sizes 2708 270 --att_sizes 1433 143
# Out:
# ten-fold:
# 0.8674 0.8538
# train radio from 0.1 to 0.9:
# 0.8108 0.7781
# 0.839 0.8195
# 0.8456 0.8255
# 0.851 0.8317
# 0.8568 0.8396
# 0.859 0.841
# 0.8604 0.8428
# 0.862 0.8429
# 0.8681 0.8495

# %%
! python classification.py --data='CiteSeer' --eta1=0.91 --eta2=0.1 --gam1=2 --gam2=2 --alpha=0.5 --mu=0.5 --ksi=0.93 --adj_sizes 3312 331 --att_sizes 3703 370
# Out:
# ten-fold:
# 0.7609 0.7148
# train radio from 0.1 to 0.9:
# 0.6835 0.6235
# 0.7046 0.6509
# 0.7207 0.6676
# 0.7282 0.6753
# 0.7379 0.6863
# 0.7436 0.6908
# 0.7484 0.6979
# 0.7417 0.6934
# 0.7447 0.6954

# %%
! python classification.py --data='Amazon' --eta1=0.91 --eta2=9.9 --gam1=9 --gam2=1 --alpha=0.62 --mu=0.11 --ksi=0.89 --adj_sizes 7650 765 --att_sizes 745 256
# Out:
# ten-fold:
# 0.9527 0.9438
# train radio from 0.1 to 0.9:
# 0.9358 0.9245
# 0.9425 0.9331
# 0.9451 0.9358
# 0.9481 0.9391
# 0.9496 0.9404
# 0.9509 0.9418
# 0.9506 0.9412
# 0.9534 0.9447
# 0.9558 0.948

# %%
! python classification.py --data='Twitch' --eta1=1.08 --eta2=1 --gam1=8 --gam2=2 --alpha=0.51 --mu=0.5 --ksi=0.89 --adj_sizes 9498 949 --att_sizes 128 128
# Out:
# ten-fold:
# 0.6897 0.6663
# train radio from 0.1 to 0.9:
# 0.6477 0.6255
# 0.6673 0.6433
# 0.6744 0.6518
# 0.6779 0.6539
# 0.6799 0.6565
# 0.6808 0.6571
# 0.6824 0.6593
# 0.6823 0.6594
# 0.6842 0.6613

# %% [markdown]
# # LinkPrediction

# %%
! python linkPrediction.py --data='WebKB' --radio='005' --eta1=0.01 --eta2=9 --gam1=6 --gam2=3 --alpha=0.56 --mu=0.2 --ksi=0.9 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python linkPrediction.py --data='WebKB' --radio='015' --eta1=0.01 --eta2=9 --gam1=6 --gam2=3 --alpha=0.56 --mu=0.2 --ksi=0.9 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python linkPrediction.py --data='WebKB' --radio='025' --eta1=0.01 --eta2=9 --gam1=6 --gam2=3 --alpha=0.56 --mu=0.2 --ksi=0.9 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python linkPrediction.py --data='WebKB' --radio='035' --eta1=0.01 --eta2=9 --gam1=6 --gam2=3 --alpha=0.56 --mu=0.2 --ksi=0.9 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python linkPrediction.py --data='WebKB' --radio='045' --eta1=0.01 --eta2=9 --gam1=6 --gam2=3 --alpha=0.56 --mu=0.2 --ksi=0.9 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
# Out:
# AUC: 0.8163 Recall: 0.7143
# AUC: 0.7567 Recall: 0.7273
# AUC: 0.7557 Recall: 0.7162
# AUC: 0.6886 Recall: 0.625
# AUC: 0.6875 Recall: 0.6418

# %%
! python linkPrediction.py --data='Cora' --radio='005' --eta1=0.037 --eta2=0.05 --gam1=4 --gam2=2 --alpha=0.49 --mu=0.2 --ksi=0.93 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='015' --eta1=0.037 --eta2=0.05 --gam1=4 --gam2=2 --alpha=0.49 --mu=0.2 --ksi=0.93 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='025' --eta1=0.037 --eta2=0.05 --gam1=4 --gam2=2 --alpha=0.49 --mu=0.2 --ksi=0.93 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='035' --eta1=0.037 --eta2=0.05 --gam1=4 --gam2=2 --alpha=0.49 --mu=0.2 --ksi=0.93 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='045' --eta1=0.037 --eta2=0.05 --gam1=4 --gam2=2 --alpha=0.49 --mu=0.2 --ksi=0.93 --adj_sizes 2708 270 --att_sizes 1433 143
# Out:
# AUC: 0.9337 Recall: 0.8524
# AUC: 0.9036 Recall: 0.8219
# AUC: 0.8928 Recall: 0.8099
# AUC: 0.8712 Recall: 0.7847
# AUC: 0.8486 Recall: 0.7614

# %%
! python linkPrediction.py --data='CiteSeer' --radio='005' --eta1=0.04 --eta2=0.1 --gam1=7 --gam2=3 --alpha=0.29 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='015' --eta1=0.04 --eta2=0.1 --gam1=7 --gam2=3 --alpha=0.29 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='025' --eta1=0.04 --eta2=0.1 --gam1=7 --gam2=3 --alpha=0.29 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='035' --eta1=0.04 --eta2=0.1 --gam1=7 --gam2=3 --alpha=0.29 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='045' --eta1=0.04 --eta2=0.1 --gam1=7 --gam2=3 --alpha=0.29 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
# Out:
# AUC: 0.9578 Recall: 0.8979
# AUC: 0.9427 Recall: 0.8769
# AUC: 0.9339 Recall: 0.8591
# AUC: 0.9283 Recall: 0.8479
# AUC: 0.919 Recall: 0.8406

# %%
! python linkPrediction.py --data='Amazon' --radio='005' --eta1=0.89 --eta2=2 --gam1=7 --gam2=2 --alpha=0.7 --mu=0.11 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python linkPrediction.py --data='Amazon' --radio='015' --eta1=0.89 --eta2=2 --gam1=7 --gam2=2 --alpha=0.7 --mu=0.11 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python linkPrediction.py --data='Amazon' --radio='025' --eta1=0.89 --eta2=2 --gam1=7 --gam2=2 --alpha=0.7 --mu=0.11 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python linkPrediction.py --data='Amazon' --radio='035' --eta1=0.89 --eta2=2 --gam1=7 --gam2=2 --alpha=0.7 --mu=0.11 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python linkPrediction.py --data='Amazon' --radio='045' --eta1=0.89 --eta2=2 --gam1=7 --gam2=2 --alpha=0.7 --mu=0.11 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
# Out:
# AUC: 0.9916 Recall: 0.9631
# AUC: 0.9905 Recall: 0.9611
# AUC: 0.9898 Recall: 0.9592
# AUC: 0.9883 Recall: 0.9552
# AUC: 0.9863 Recall: 0.9501

# %%
! python linkPrediction.py --data='Twitch' --radio='005' --eta1=0.72 --eta2=0.2 --gam1=10 --gam2=2 --alpha=0.5 --mu=0.8 --ksi=0.88 --adj_sizes 9498 949 --att_sizes 128 128
! python linkPrediction.py --data='Twitch' --radio='015' --eta1=0.72 --eta2=0.2 --gam1=10 --gam2=2 --alpha=0.5 --mu=0.8 --ksi=0.88 --adj_sizes 9498 949 --att_sizes 128 128
! python linkPrediction.py --data='Twitch' --radio='025' --eta1=0.72 --eta2=0.2 --gam1=10 --gam2=2 --alpha=0.5 --mu=0.8 --ksi=0.88 --adj_sizes 9498 949 --att_sizes 128 128
! python linkPrediction.py --data='Twitch' --radio='035' --eta1=0.72 --eta2=0.2 --gam1=10 --gam2=2 --alpha=0.5 --mu=0.8 --ksi=0.88 --adj_sizes 9498 949 --att_sizes 128 128
! python linkPrediction.py --data='Twitch' --radio='045' --eta1=0.72 --eta2=0.2 --gam1=10 --gam2=2 --alpha=0.5 --mu=0.8 --ksi=0.88 --adj_sizes 9498 949 --att_sizes 128 128
# Out:
# AUC: 0.9253 Recall: 0.856
# AUC: 0.9211 Recall: 0.8497
# AUC: 0.916 Recall: 0.8437
# AUC: 0.9085 Recall: 0.8335
# AUC: 0.9004 Recall: 0.8254

# %% [markdown]
# # AttributePrediction

# %%
! python attributePrediction.py --data='WebKB' --radio='005' --eta1=0.4 --eta2=0.7 --gam1=8 --gam2=5 --alpha=0.56 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python attributePrediction.py --data='WebKB' --radio='015' --eta1=0.4 --eta2=0.7 --gam1=8 --gam2=5 --alpha=0.56 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python attributePrediction.py --data='WebKB' --radio='025' --eta1=0.4 --eta2=0.7 --gam1=8 --gam2=5 --alpha=0.56 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python attributePrediction.py --data='WebKB' --radio='035' --eta1=0.4 --eta2=0.7 --gam1=8 --gam2=5 --alpha=0.56 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
! python attributePrediction.py --data='WebKB' --radio='045' --eta1=0.4 --eta2=0.7 --gam1=8 --gam2=5 --alpha=0.56 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
# Out:
# AUC: 0.8599 Recall: 0.7935
# AUC: 0.8491 Recall: 0.7769
# AUC: 0.8341 Recall: 0.7675
# AUC: 0.8229 Recall: 0.7592
# AUC: 0.7986 Recall: 0.7359

# %%
! python linkPrediction.py --data='Cora' --radio='005' --eta1=0.4 --eta2=0.03 --gam1=2 --gam2=5 --alpha=0.49 --mu=0.05 --ksi=0.96 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='015' --eta1=0.4 --eta2=0.03 --gam1=2 --gam2=5 --alpha=0.49 --mu=0.05 --ksi=0.96 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='025' --eta1=0.4 --eta2=0.03 --gam1=2 --gam2=5 --alpha=0.49 --mu=0.05 --ksi=0.96 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='035' --eta1=0.4 --eta2=0.03 --gam1=2 --gam2=5 --alpha=0.49 --mu=0.05 --ksi=0.96 --adj_sizes 2708 270 --att_sizes 1433 143
! python linkPrediction.py --data='Cora' --radio='045' --eta1=0.4 --eta2=0.03 --gam1=2 --gam2=5 --alpha=0.49 --mu=0.05 --ksi=0.96 --adj_sizes 2708 270 --att_sizes 1433 143
# Out:
# AUC: 0.9189 Recall: 0.8413
# AUC: 0.8892 Recall: 0.812
# AUC: 0.871 Recall: 0.7819
# AUC: 0.8428 Recall: 0.7542
# AUC: 0.8139 Recall: 0.7266

# %%
! python linkPrediction.py --data='CiteSeer' --radio='005' --eta1=0.017 --eta2=0.011 --gam1=9 --gam2=7 --alpha=0.02 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='015' --eta1=0.017 --eta2=0.011 --gam1=9 --gam2=7 --alpha=0.02 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='025' --eta1=0.017 --eta2=0.011 --gam1=9 --gam2=7 --alpha=0.02 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='035' --eta1=0.017 --eta2=0.011 --gam1=9 --gam2=7 --alpha=0.02 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
! python linkPrediction.py --data='CiteSeer' --radio='045' --eta1=0.017 --eta2=0.011 --gam1=9 --gam2=7 --alpha=0.02 --mu=0.049 --ksi=0.8 --adj_sizes 3312 331 --att_sizes 3703 370
# Out:
# AUC: 0.9577 Recall: 0.8851
# AUC: 0.9428 Recall: 0.8713
# AUC: 0.9322 Recall: 0.8506
# AUC: 0.9214 Recall: 0.8352
# AUC: 0.9158 Recall: 0.8322

# %%
! python attributePrediction.py --data='Amazon' --radio='005' --eta1=0.08 --eta2=2 --gam1=5 --gam2=1 --alpha=0.65 --mu=0.2 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python attributePrediction.py --data='Amazon' --radio='015' --eta1=0.08 --eta2=2 --gam1=5 --gam2=1 --alpha=0.65 --mu=0.2 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python attributePrediction.py --data='Amazon' --radio='025' --eta1=0.08 --eta2=2 --gam1=5 --gam2=1 --alpha=0.65 --mu=0.2 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python attributePrediction.py --data='Amazon' --radio='035' --eta1=0.08 --eta2=2 --gam1=5 --gam2=1 --alpha=0.65 --mu=0.2 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
! python attributePrediction.py --data='Amazon' --radio='045' --eta1=0.08 --eta2=2 --gam1=5 --gam2=1 --alpha=0.65 --mu=0.2 --ksi=0.91 --adj_sizes 7650 765 --att_sizes 745 256
# Out:
# AUC: 0.8726 Recall: 0.7874
# AUC: 0.8723 Recall: 0.7874
# AUC: 0.8707 Recall: 0.7866
# AUC: 0.8694 Recall: 0.7851
# AUC: 0.8674 Recall: 0.7838

# %% [markdown]
# # OutlierDetection

# %%
! python outlierDetection.py --data='WebKB' --eta1=1000 --eta2=0.05 --gam1=2 --gam2=1 --alpha=0.5 --mu=0.5 --ksi=0.9 --adj_sizes 192 128 --att_sizes 1703 170
# Out:
# AUC: 0.888
# Recall@25%: 1.0

# %%
! python outlierDetection.py --data='Cora' --eta1=10000 --eta2=0.11 --gam1=1 --gam2=2 --alpha=0.01 --mu=0.68 --ksi=0.91 --adj_sizes 2843 284 --att_sizes 1433 143
# Out:
# AUC: 0.8011
# Recall@25%: 0.6667

# %%
! python outlierDetection.py --data='CiteSeer' --eta1=10000 --eta2=0.5 --gam1=1 --gam2=2 --alpha=0.47 --mu=0.7 --ksi=0.92 --adj_sizes 3477 347 --att_sizes 3703 370
# Out:
# AUC: 0.8434
# Recall@25%: 0.6848

# %%
! python outlierDetection.py --data='Amazon' --eta1=500 --eta2=1.5 --gam1=1 --gam2=6 --alpha=0.3 --mu=0.8 --ksi=0.92 --adj_sizes 8032 803 --att_sizes 745 256
# Out:
# AUC: 0.9
# Recall@25%: 0.9136

# %%
! python outlierDetection.py --data='Twitch' --eta1=1000 --eta2=0.2 --gam1=1 --gam2=4 --alpha=0.45 --mu=0.7 --ksi=0.92 --adj_sizes 9972 997 --att_sizes 128 128
# Out:
# AUC: 0.7117
# Recall@25%: 0.4177

# %% [markdown]
# # Visualization

# %%
! python visualization.py --data='WebKB' --eta1=0.2 --eta2=10 --gam1=3 --gam2=3 --alpha=0.56 --mu=0.4 --ksi=0.8 --adj_sizes 183 128 --att_sizes 1703 170 --hidden_sizes 64
# Out:
# SC: 0.1801 CHS: 43.7799

# %%
! python visualization.py --data='Cora' --eta1=0.009 --eta2=0.05 --gam1=11 --gam2=2 --alpha=0.51 --mu=0.5 --ksi=0.91 --adj_sizes 2708 270 --att_sizes 1433 143
# Out:
# SC: 0.2207 CHS: 886.6639

# %%
! python visualization.py --data='CiteSeer' --eta1=0.91 --eta2=0.1 --gam1=4 --gam2=3 --alpha=0.46 --mu=0.5 --ksi=0.93 --adj_sizes 3312 331 --att_sizes 3703 370
# Out:
# SC: 0.1276 CHS: 711.5256

# %%
! python visualization.py --data='Amazon' --eta1=0.09 --eta2=4.1 --gam1=6 --gam2=2 --alpha=0.62 --mu=0.11 --ksi=0.89 --adj_sizes 7650 765 --att_sizes 745 256
# Out:
# SC: 0.2487 CHS: 2665.0263

# %%
! python visualization.py --data='Twitch' --eta1=9.5 --eta2=0.011 --gam1=18 --gam2=2 --alpha=0.4 --mu=0.7 --ksi=0.88 --adj_sizes 9498 949 --att_sizes 128 128
# Out:
# SC: 0.0428 CHS: 400.985
